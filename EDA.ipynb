# %%
import time

import numpy as np
import pandas as pd

from pandas_profiling import ProfileReport

import matplotlib.pyplot as plt
import seaborn as sns

# %%
calendar_data = pd.read_csv('Data/calendar.csv')
sales_data = pd.read_csv('Data/sales_train_validation.csv')
weekly_sale_price_data = pd.read_csv('Data/sell_prices.csv')

# %%
calendar_data['date'] = pd.DatetimeIndex(calendar_data.date)

# %%
calendar_data.head(5)
# Out:
#         date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0 2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1 2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2 2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3 2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4 2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
calendar_data.tail()
# Out:
#            date  wm_yr_wk    weekday  wday  month  year       d  event_name_1  \
# 1964 2016-06-15     11620  Wednesday     5      6  2016  d_1965           NaN
# 1965 2016-06-16     11620   Thursday     6      6  2016  d_1966           NaN
# 1966 2016-06-17     11620     Friday     7      6  2016  d_1967           NaN
# 1967 2016-06-18     11621   Saturday     1      6  2016  d_1968           NaN
# 1968 2016-06-19     11621     Sunday     2      6  2016  d_1969  NBAFinalsEnd
#
#      event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 1964          NaN           NaN          NaN        0        1        1
# 1965          NaN           NaN          NaN        0        0        0
# 1966          NaN           NaN          NaN        0        0        0
# 1967          NaN           NaN          NaN        0        0        0
# 1968     Sporting  Father's day     Cultural        0        0        0

# %%
calendar_data.tail(5)
# Out:
#            date  wm_yr_wk    weekday  wday  month  year       d  event_name_1  \
# 1964 2016-06-15     11620  Wednesday     5      6  2016  d_1965           NaN
# 1965 2016-06-16     11620   Thursday     6      6  2016  d_1966           NaN
# 1966 2016-06-17     11620     Friday     7      6  2016  d_1967           NaN
# 1967 2016-06-18     11621   Saturday     1      6  2016  d_1968           NaN
# 1968 2016-06-19     11621     Sunday     2      6  2016  d_1969  NBAFinalsEnd
#
#      event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 1964          NaN           NaN          NaN        0        1        1
# 1965          NaN           NaN          NaN        0        0        0
# 1966          NaN           NaN          NaN        0        0        0
# 1967          NaN           NaN          NaN        0        0        0
# 1968     Sporting  Father's day     Cultural        0        0        0

# %%
sales_data.head(10)
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
# 5  HOBBIES_1_006_CA_1_validation  HOBBIES_1_006  HOBBIES_1  HOBBIES     CA_1
# 6  HOBBIES_1_007_CA_1_validation  HOBBIES_1_007  HOBBIES_1  HOBBIES     CA_1
# 7  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1
# 8  HOBBIES_1_009_CA_1_validation  HOBBIES_1_009  HOBBIES_1  HOBBIES     CA_1
# 9  HOBBIES_1_010_CA_1_validation  HOBBIES_1_010  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  d_1908  \
# 0       CA    0    0    0    0  ...       1       3       0       1       1
# 1       CA    0    0    0    0  ...       0       0       0       0       0
# 2       CA    0    0    0    0  ...       2       1       2       1       1
# 3       CA    0    0    0    0  ...       1       0       5       4       1
# 4       CA    0    0    0    0  ...       2       1       1       0       1
# 5       CA    0    0    0    0  ...       0       1       0       1       0
# 6       CA    0    0    0    0  ...       0       0       0       1       0
# 7       CA   12   15    0    0  ...       0       0       1      37       3
# 8       CA    2    0    7    3  ...       0       0       1       1       6
# 9       CA    0    0    1    0  ...       1       0       0       0       0
#
#    d_1909  d_1910  d_1911  d_1912  d_1913
# 0       1       3       0       1       1
# 1       1       0       0       0       0
# 2       1       0       1       1       1
# 3       0       1       3       7       2
# 4       1       2       2       2       4
# 5       0       0       2       0       0
# 6       1       0       0       1       1
# 7       4       6       3       2       1
# 8       0       0       0       0       0
# 9       0       0       2       0       2
#
# [10 rows x 1919 columns]

# %%
sales_data_long = pd.melt(sales_data, 
                          id_vars = sales_data.columns[:6], value_vars = sales_data.columns[6:], 
                          var_name = 'd', value_name = 'sales')

# %%
sales_data_long.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  sales
# 0       CA  d_1      0
# 1       CA  d_1      0
# 2       CA  d_1      0
# 3       CA  d_1      0
# 4       CA  d_1      0

# %%
sales_data_long.shape
# Out:
# (58327370, 8)

# %%
weekly_sale_price_data.head(5)
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %%
# %%time
# calendar_profile = calendar_data.profile_report(title = 'M5 Forecasting - Calendar Data Profile')
# calendar_profile.to_file(output_file = "Calendar_Data_Profile.html")

# %%
# %%time
# sales_data_ids_profile = sales_data.iloc[:, :6].profile_report(title = 'M5 Forecasting - Sales Data IDs Profile')
# sales_data_ids_profile.to_file(output_file = "Sales_Data_IDs_Profile.html")

# %%
# %%time
# weekly_sale_price_data_profile = weekly_sale_price_data.profile_report(title = 'M5 Forecasting - Weekly Sale Price Data Profile')
# weekly_sale_price_data_profile.to_file(output_file = "Weekly_Sale_Price_Data_Profile.html")

# %%
day_cols = sales_data.columns[6:]
averaged_item_sales = sales_data.groupby('item_id')[day_cols].mean().T

# %%
averaged_item_sales.head()
# Out:
# item_id  FOODS_1_001  FOODS_1_002  FOODS_1_003  FOODS_1_004  FOODS_1_005  \
# d_1              0.6          0.4          1.4          0.0          3.4
# d_2              0.6          0.5          0.8          0.0          3.2
# d_3              0.4          0.7          0.3          0.0          1.3
# d_4              0.6          0.4          0.6          0.0          2.0
# d_5              0.7          0.3          0.3          0.0          1.0
#
# item_id  FOODS_1_006  FOODS_1_008  FOODS_1_009  FOODS_1_010  FOODS_1_011  ...  \
# d_1              1.6          0.0          0.0          0.0          0.7  ...
# d_2              0.9          0.0          0.0          0.0          0.1  ...
# d_3              2.0          0.0          0.0          0.0          0.5  ...
# d_4              1.6          0.0          0.0          0.0          0.1  ...
# d_5              1.4          0.0          0.0          0.0          0.0  ...
#
# item_id  HOUSEHOLD_2_507  HOUSEHOLD_2_508  HOUSEHOLD_2_509  HOUSEHOLD_2_510  \
# d_1                  0.0              0.0              0.8              0.0
# d_2                  0.0              0.0              1.0              0.0
# d_3                  0.0              0.0              1.2              0.0
# d_4                  0.0              0.0              0.8              0.0
# d_5                  0.0              0.0              0.9              0.0
#
# item_id  HOUSEHOLD_2_511  HOUSEHOLD_2_512  HOUSEHOLD_2_513  HOUSEHOLD_2_514  \
# d_1                  2.0              0.5              0.0              0.4
# d_2                  2.4              0.4              0.0              0.8
# d_3                  0.7              0.1              0.0              0.2
# d_4                  0.7              0.3              0.0              0.1
# d_5                  0.9              0.2              0.0              0.1
#
# item_id  HOUSEHOLD_2_515  HOUSEHOLD_2_516
# d_1                  0.0              0.2
# d_2                  0.0              0.4
# d_3                  0.0              0.0
# d_4                  0.0              0.3
# d_5                  0.0              0.1
#
# [5 rows x 3049 columns]

# %%
# %%time
# averaged_item_sales_profile = averaged_item_sales.profile_report(title = 'M5 Forecasting - Averaged Item Sales Profile', 
#                                                                  pool_size = 8)
# averaged_item_sales_profile.to_file(output_file = "Averaged_Item_Sales_Profile.html")

# %%
item_sales_corrs = averaged_item_sales.corr()

# %%
item_sales_corrs.head()
# Out:
# item_id      FOODS_1_001  FOODS_1_002  FOODS_1_003  FOODS_1_004  FOODS_1_005  \
# item_id
# FOODS_1_001     1.000000     0.064179     0.211582    -0.010271     0.073942
# FOODS_1_002     0.064179     1.000000     0.089203     0.059364     0.063977
# FOODS_1_003     0.211582     0.089203     1.000000    -0.033026     0.067111
# FOODS_1_004    -0.010271     0.059364    -0.033026     1.000000    -0.115341
# FOODS_1_005     0.073942     0.063977     0.067111    -0.115341     1.000000
#
# item_id      FOODS_1_006  FOODS_1_008  FOODS_1_009  FOODS_1_010  FOODS_1_011  \
# item_id
# FOODS_1_001     0.071094    -0.005278     0.094565    -0.094671     0.096496
# FOODS_1_002     0.052831     0.025301     0.039285     0.002755     0.044322
# FOODS_1_003     0.149153    -0.024213    -0.000274    -0.202621     0.008750
# FOODS_1_004    -0.069658     0.187809     0.275041     0.106399     0.094413
# FOODS_1_005     0.107712     0.131129     0.007023     0.045568     0.009713
#
# item_id      ...  HOUSEHOLD_2_507  HOUSEHOLD_2_508  HOUSEHOLD_2_509  \
# item_id      ...
# FOODS_1_001  ...         0.168518        -0.002739         0.046350
# FOODS_1_002  ...         0.071718        -0.011928         0.056039
# FOODS_1_003  ...         0.157196        -0.068634         0.109294
# FOODS_1_004  ...         0.042018         0.243229         0.044265
# FOODS_1_005  ...        -0.005825        -0.030868         0.071406
#
# item_id      HOUSEHOLD_2_510  HOUSEHOLD_2_511  HOUSEHOLD_2_512  \
# item_id
# FOODS_1_001         0.089426         0.282171         0.081103
# FOODS_1_002         0.083764         0.080868         0.043698
# FOODS_1_003         0.121859         0.284644         0.089435
# FOODS_1_004         0.157336        -0.210491         0.020233
# FOODS_1_005        -0.030238         0.181653        -0.122469
#
# item_id      HOUSEHOLD_2_513  HOUSEHOLD_2_514  HOUSEHOLD_2_515  \
# item_id
# FOODS_1_001        -0.237706         0.083987        -0.109812
# FOODS_1_002        -0.020029         0.064594         0.052431
# FOODS_1_003        -0.223661         0.096967        -0.230040
# FOODS_1_004         0.189544         0.080369         0.075623
# FOODS_1_005        -0.134085         0.082702        -0.013597
#
# item_id      HOUSEHOLD_2_516
# item_id
# FOODS_1_001        -0.005735
# FOODS_1_002         0.044144
# FOODS_1_003         0.018501
# FOODS_1_004         0.007249
# FOODS_1_005         0.086135
#
# [5 rows x 3049 columns]

# %% [markdown]
# ### Calendar Data

# %%
calendar_data.head(10)

# %%
calendar_data['day_of_month'] = pd.DatetimeIndex(calendar_data.date).day

# %%
print('start date:', calendar_data.date.min())
print('end date:', calendar_data.date.max())
print('num days:', len(calendar_data))

# %%
print('Event Name 1:', calendar_data.event_name_1.unique())
print('Event Type_1:', calendar_data.event_type_1.value_counts())

# %%
print('Event Name 2:', calendar_data.event_name_2.value_counts())
print('Event Type_2:', calendar_data.event_type_2.value_counts())

# %%
first_year = calendar_data[calendar_data['date'] < '2012-01-29']
first_year.groupby('day_of_month')[['snap_CA', 'snap_TX', 'snap_WI']].sum()

# %% [markdown]
# ### Sales Data Wide

# %%
sales_data.head(10)

# %%
sales_data.shape

# %%
id_values = sales_data[['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']].drop_duplicates()

# %%
print('Categories:', id_values.cat_id.unique())
print('Departments:', id_values.dept_id.unique())
print('Stores:', id_values.store_id.unique())

# %%
id_values.groupby(['cat_id', 'dept_id']).item_id.nunique()

# %%
id_values.describe()

# %%
id_values.isnull().any()

# %%
any(sales_data.isna().any() == True)

# %%
any(sales_data.iloc[:, 6:].min() < 0)

# %% [markdown]
# ### Sales Data Long

# %%
sales_data_long.head()

# %%
sales_data_long['d'] = sales_data_long.d.apply(lambda x: x.split('_')[1]).astype(int)

# %%
d_max = sales_data_long['d'].max()
sales_data_long_2 = sales_data_long[sales_data_long['d'] >= (d_max-180)]
sales_data_long_2.shape

# %%
sales_data_long_2.head()

# %%
plt.hist(sales_data_long_2.groupby('item_id').sales.mean())

# %%
plt.hist(sales_data_long_2.groupby('item_id').sales.mean())
